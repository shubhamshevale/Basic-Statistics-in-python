# %%
# !pip install pandas

# %%
import pandas as pd

# %%
a=pd.read_csv("C://excelrdata//Q7.csv")
a
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
mean_Points=a.Points.mean()
median_Points=a.Points.median()
mode_Points=a.Points.mode()
var_Points=a.Points.var()
std_Points=a.Points.std()

# %%
print("#RESULT FOR POINTS","\nMean:", mean_Points, "\nMedian:",median_Points,"\nMode:",mode_Points,"\nVarience",var_Points,"\nStandard deviation",std_Points,)
# Out:
# #RESULT FOR POINTS
# Mean: 3.5965625000000006
# Median: 3.6950000000000003
# Mode: 0    3.07
# 1    3.92
# dtype: float64
# Varience 0.28588135080645166
# Standard deviation 0.5346787360709716

# %%
mean_Score=a.Score.mean()
median_Score=a.Score.median()
mode_Score=a.Score.mode()
var_Score=a.Score.var()
std_Score=a.Score.std()

# %%
print("#RESULT FOR SCORE","\nMean:", mean_Score, "\nMedian:",median_Score,"\nMode:",mode_Score,"\nVarience",var_Score,"\nStandard deviation",std_Score,)
# Out:
# #RESULT FOR SCORE
# Mean: 3.2172499999999995
# Median: 3.325
# Mode: 0    3.44
# dtype: float64
# Varience 0.9573789677419356
# Standard deviation 0.9784574429896967

# %%
mean_Weigh=a.Weigh.mean()
median_Weigh=a.Weigh.median()
mode_Weigh=a.Weigh.mode()
var_Weigh=a.Weigh.var()
std_Weigh=a.Weigh.std()

# %%
print("#RESULT FOR WEIGH","\nMean:", mean_Weigh, "\nMedian:",median_Weigh,"\nMode:",mode_Weigh,"\nVarience",var_Weigh,"\nStandard deviation",std_Weigh,)
# Out:
# #RESULT FOR WEIGH
# Mean: 17.848750000000003
# Median: 17.71
# Mode: 0    17.02
# 1    18.90
# dtype: float64
# Varience 3.193166129032258
# Standard deviation 1.7869432360968431
